# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option("display.max_columns", None)

df = pd.read_csv("../data/raw/RetailCustomers.csv")

df.head()
# Out:
#    CustomerID  Recency  Frequency  MonetaryTotal  MonetaryAvg  MonetaryStd  \
# 0       17850      302         35        5288.63    16.950737    13.603662
# 1       13047       32         18        3079.10    15.709694    11.684769
# 2       12583        3         18        7187.34    28.634821    23.150132
# 3       13748       96          5         948.25    33.866071    42.953119
# 4       15100      330          6         635.10   105.850000   215.986263
#
#    MonetaryMin  MonetaryMax  TotalQuantity  AvgQuantityPerTransaction  \
# 0       -30.60       107.25           1693                   5.426282
# 1       -15.00        68.00           1355                   6.913265
# 2       -60.84       132.80           5009                  19.956175
# 3         9.36       204.00            439                  15.678571
# 4      -131.40       350.40             58                   9.666667
#
#    MinQuantity  MaxQuantity  CustomerTenureDays  FirstPurchaseDaysAgo  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4372 entries, 0 to 4371
# Data columns (total 52 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   CustomerID                 4372 non-null   int64
#  1   Recency                    4372 non-null   int64
#  2   Frequency                  4372 non-null   int64
#  3   MonetaryTotal              4372 non-null   float64
#  4   MonetaryAvg                4372 non-null   float64
#  5   MonetaryStd                4372 non-null   float64
#  6   MonetaryMin                4372 non-null   float64
#  7   MonetaryMax                4372 non-null   float64
#  8   TotalQuantity              4372 non-null   int64
#  9   AvgQuantityPerTransaction  4372 non-null   float64
#  10  MinQuantity                4372 non-null   int64
#  11  MaxQuantity                4372 non-null   int64
#  12  CustomerTenureDays         4372 non-null   int64
# ...

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# Age                          1311
# AvgDaysBetweenPurchases        79
# Frequency                       0
# CustomerID                      0
# MonetaryTotal                   0
# MonetaryAvg                     0
# MonetaryMin                     0
# MonetaryStd                     0
# TotalQuantity                   0
# AvgQuantityPerTransaction       0
# MinQuantity                     0
# MonetaryMax                     0
# MaxQuantity                     0
# CustomerTenureDays              0
# PreferredDayOfWeek              0
# FirstPurchaseDaysAgo            0
# PreferredHour                   0
# PreferredMonth                  0
# WeekendPurchaseRatio            0
# Recency                         0
# UniqueProducts                  0
# UniqueDescriptions              0
# UniqueCountries                 0
# AvgProductsPerTransaction       0
# ZeroPriceCount                  0
# CancelledTransactions           0
# ReturnRatio                     0
# ...

# %%
df["Churn"].value_counts()
df["Churn"].value_counts(normalize=True)
# Out:
# Churn
# 0    0.667429
# 1    0.332571
# Name: proportion, dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.countplot(x="Churn", data=df)
plt.title("Distribution du Churn")
plt.show()

# %%
df = pd.read_csv("../data/raw/RetailCustomers.csv")

# %%
pd.crosstab(df["ChurnRiskCategory"], df["Churn"])
# Out:
# Churn                 0     1
# ChurnRiskCategory
# Critique              0  1454
# Faible             1695     0
# Moyen               743     0
# Élevé               480     0

# %%
pd.crosstab(df["AccountStatus"], df["Churn"])
# Out:
# Churn             0     1
# AccountStatus
# Active         2642  1302
# Closed           60    24
# Pending          85    46
# Suspended       131    82

# %%
pd.crosstab(df["RFMSegment"], df["Churn"])
# Out:
# Churn          0    1
# RFMSegment
# Champions    979    0
# Dormants       0  627
# Fidèles     1067  110
# Potentiels   872  717

# %%
pd.crosstab(df["LoyaltyLevel"], df["Churn"])
# Out:
# Churn            0    1
# LoyaltyLevel
# Ancien         100    0
# Jeune          597  373
# Nouveau        777  937
# Établi        1444  144

# %%
df[["Recency", "Churn"]].groupby("Churn").describe()
# Out:
#       Recency
#         count        mean        std   min    25%    50%     75%    max
# Churn
# 0      2918.0   30.957162  24.720707   1.0    9.0   24.0   50.00   90.0
# 1      1454.0  214.647180  82.353601  91.0  143.0  205.0  277.75  374.0

# %%
pd.crosstab(df["Recency"] > 200, df["Churn"])
# Out:
# Churn       0    1
# Recency
# False    2918  703
# True        0  751
